# %%
import requests  
from bs4 import BeautifulSoup

# %%
url = "https://honey.com/honey-industry/statistics/retail-honey-price"
page = requests.get(url)

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.content)
# Out:
# b'<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" lang="en-US">\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n\n\n    <!-- Google Tag Manager -->\n    <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n                new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n            j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n            \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n        })(window,document,\'script\',\'dataLayer\',\'GTM-MMPVS4Q\');</script>\n    <!-- End Google Tag Manager -->\n\n\n    <link rel="apple-touch-icon" sizes="180x180" href="/assets/images/favicons/apple-touch-icon.png">\n    <link rel="icon" type="image/png" sizes="32x32" href="/assets/images/favicons/favicon-32x32.png">\n    <link rel="icon" type="image/png" sizes="16x16" href="/assets/images/favicons/favicon-16x16.png">\n    <link rel="manifest" href="/assets/images/favicons/site.webmanifest">\n    <link rel="mask-icon" href="/assets/images/favicons/safari-pinned-tab.svg" color="#fdc13b">\n    <link rel="shortcut icon" href="/assets/images/favicons/favicon.ico">\n    <meta name="msapplication-TileColor" content="#fdc13b">\n    <meta name="msapplication-config" content="/assets/images/favicons/browserconfig.xml">\n    <meta name="theme-color" content="#ffffff">\n\n\n    <link rel="stylesheet" href="/assets/css/main.css">\n\n\n\n    <!-- HTML5 shiv and Respond.js IE8 support of HTML5 elements and media queries -->\n    <!--[if lt IE 9]>\n    <script src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7/html5shiv.min.js"></script>\n    <script src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.min.js"></script>\n    <![endif]-->\n    <!--[if lt IE 9]>\n    <div class="alert alert-warning">\n        You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.\n    </div>\n    <![endif]-->\n\n\n<title>Retail Honey Prices | National Honey Board</title><meta name="generator" content="SEOmatic">\n<meta name="referrer" content="no-referrer-when-downgrade">\n<meta name="robots" content="all">\n<meta content="en_US" property="og:locale">\n<meta content="National Honey Board" property="og:site_name">\n<meta content="website" property="og:type">\n<meta content="https://honey.com/honey-industry/statistics/retail-honey-price" property="og:url">\n<meta content="Retail Honey Prices" property="og:title">\n<link href="https://honey.com/honey-industry/statistics/retail-honey-price" rel="canonical">\n<link href="https://honey.com" rel="home">\n<link type="text/plain" href="https://honey.com/humans.txt" rel="author">\n<link href="https://honey.com/cpresources/654bcd49/ccc.css?v=1608136305" rel="stylesheet">\n<script>var cccSiteUrl = "https://honey.com/";</script></head>\n\n    \n    \n<body class="page honey-industry-section" style=" ">\n<!-- Google Tag Manager (noscript) -->\n<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MMPVS4Q"\n                  height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>\n<!-- End Google Tag Manager (noscript) -->\n\n    \n        \n<div id="container">\n\n    \n<div class="header-space"></div>\n<header id="header" class="header fixed-header">\n        <div class="container">\n            <div class="row justify-content-between">\n                <div class="col-9 col-md-1 col-lg-2 logo-header ">\n                    <a class="navbar-brand" href="https://honey.com/">\n                                                    <img class="img-fluid" src="/images/default/honey-logo-white.svg" alt="" title="National Honey Board"/>\n                                            </a>\n                </div>\n\n\n                <nav class= ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-MMPVS4Q');
#   </script>
#   <!-- End Google Tag Manager -->
#   <link href="/assets/images/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/assets/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/assets/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/assets/images/favicons/site.webmanifest" rel="manifest"/>
#   <link color="#fdc13b" href="/assets/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link href="/assets/images/favicons/favicon.ico" rel="shortcut icon"/>
#   <meta content="#fdc13b" name="msapplication-TileColor"/>
#   <meta content="/assets/images/favicons/browserconfig.xml" name="msapplication-config"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link href="/assets/css/main.css" rel="stylesheet"/>
#   <!-- HTML5 shiv and Respond.js IE8 support of HTML5 elements and media queries -->
#   <!--[if lt IE 9]>
#     <script src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7/html5shiv.min.js"></script>
#     <script src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.min.js"></script>
#     <![endif]-->
#   <!--[if lt IE 9]>
#     <div class="alert alert-warning">
#         You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.
#     </div>
#     <![endif]-->
#   <title>
#    Retail Honey Prices | National Honey Board
#   </title>
#   <meta content="SEOmatic" name="generator"/>
#   <meta content="no-referrer-when-downgrade" name="referrer"/>
#   <meta content="all" name="robots"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="National Honey Board" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://honey.com/honey-industry/statistics/retail-honey-price" property="og:url"/>
#   <meta content="Retail Honey Prices" property="og:title"/>
#   <link href="https://honey.com/honey-industry/statistics/retail-honey-price" rel="canonical"/>
#   <link href="https://honey.com" rel="home"/>
#   <link href="https://honey.com/humans.txt" rel="author" type="text/plain"/>
#   <link href="https://honey.com/cpresources/654bcd49/ccc.css?v=1608136305" rel="stylesheet"/>
#   <script>
#    var cccSiteUrl = "https://honey.com/";
#   </script>
#  </head>
#  <body class="page honey-industry-section" style=" ">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MMPVS4Q" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div id="container">
#    <div class="header-space">
#    </div>
#    <header class="header fixed-header" id="header">
#     <div class="container">
#      <div class="row justify-content-between">
#       <div class="col-9 col-md-1 col-lg-2 logo-header">
#        <a class="navbar-brand" href="https://honey.com/">
#         <img alt="" class="img-fluid" src="/images/default/honey-logo-white.svg" title="National Honey Board"/>
#        </a>
#       </div>
#       <nav class="nav navbar navbar-expand-lg col-12 col-md-12 col-lg-8">
#        <button aria-controls="primaryNavigation" aria-expanded="false" aria-label="Toggle primary navigation" class="navbar-toggler" data-target="#primaryNavigation" data-toggle="collapse" type="button">
#         <span class="navbar-toggler-text">
#          <span class="spinner2 diagonal part-1">
#          </span>
#          <span class="spinner2 horizontal">
#          </span>
#          <span class="spinner2 diagonal part-2">
#          </span>
#         </span>
#        </button>
#        <div class="collapse navbar-collapse navbar-nav nav-wrap" id="primaryNavigation">
#         <ul class="navbar-nav ml-auto">
#          <li class="nav-item">
#           <a class="nav-link active" href="https://honey.com/honey-industry">
#            Industry Home
#           </a>
#          </li>
#          <li class="nav-item">
#           <a class="nav-link active" href="https://honey.com/honey-industry/statistics">
#            Statistics
#           </a>
#          </li>
#          <li class="nav-item">
#           <a class="nav-link" href="https://honey.com/honey-industry/research">
#            Research
#           </a>
#          </li>
#          <li class="nav-item">
#           <a class="nav-link" href="https://honey.com/honey-industry/regulation">
#            Regulation
#           </a>
#          </li>
#          <li class="nav-item">
#           <a class="nav-link" href="https://honey.com/honey-industry/member-reporting">
#            Reporting
#           </a>
#          </li>
#          <li class="nav-item">
#           <a class="nav-link" href="/search">
#            <i class="fas fa-search">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </nav>
#       <div class="section-navigation col-12 col-md-3 col-lg-2">
#        <button aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" id="sectionNav" type="button">
#         Industry &amp; Partners
#        </button>
#        <ul aria-labelledby="sectionNav" class="dropdown-menu">
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/">
#           Consumers
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/food-processors">
#           Food Processors
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/foodservice">
#           Foodservice
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/retail">
#           Retail
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link active" href="https://honey.com/honey-industry">
#           Industry
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/nutrition">
#           Nutrition Home
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </header>
#    <main id="content" role="main">
#     <section class="block subNavigation" id="block_1_subNavigation">
#      <div class="container-xl">
#       <div class="row">
#        <div class="col-12">
#         <ul class="sub-nav link-yellow">
#          <li class="nav-items">
#           <a href="https://honey.com/honey-industry/statistics">
#            Statistics
#           </a>
#          </li>
#          <li class="nav-items">
#           <a class="active" href="https://honey.com/honey-industry/statistics/retail-honey-price">
#            Retail Honey Prices
#           </a>
#          </li>
#          <li class="nav-items">
#           <a href="https://honey.com/honey-industry/statistics/wholesale-honey-price">
#            Wholesale Honey Prices
#           </a>
#          </li>
#          <li class="nav-items">
#           <a href="https://honey.com/honey-industry/statistics/international-bulk-prices">
#            International Bulk Prices
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="block contentGrid" id="block_2_contentGrid">
#      <div class="container-xl">
#       <div class="row">
#        <div class="col-12 col-md-12">
#         <h1>
#          <span style="color:rgb(253,193,59);">
#           RETAIL HONEY PRICES
#          </span>
#         </h1>
#         <p>
#          <strong>
#           Unit Honey Prices by Month – Retail
#          </strong>
#         </p>
#         <p>
#          Average retail price per pound across all reporting regions. Data from
#          <em>
#           Bee Culture
#          </em>
#          magazine used by permission. Based upon average price across all reporting regions. Assumes various sizes sold at the same rate.
#         </p>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="block table white" id="block_3_table">
#      <div class="container-xl">
#       <div class="row">
#        <div class="col-12">
#         <div class="table-responsive">
#          <table class="table table-bordered">
#           <thead>
#            <tr>
#             <th scope="col">
#             </th>
#             <th scope="col">
#              Jan
#             </th>
#             <th scope="col">
#              Feb
#             </th>
#             <th scope="col">
#              Mar
#             </th>
#             <th scope="col">
#              Apr
#             </th>
#             <th scope="col">
#              May
#             </th>
#             <th scope="col">
#              Jun
#             </th>
#             <th scope="col">
#              Jul
#             </th>
#             <th scope="col">
#              Aug
#             </th>
#             <th scope="col">
#              Sep
#             </th>
#             <th scope="col">
#              Oct
#             </th>
#             <th scope="col">
#              Nov
#             </th>
#             <th scope="col">
#              Dev
#             </th>
#            </tr>
#           </thead>
#           <tbody>
#            <tr>
#             <td scope="row">
#              2020
#             </td>
#             <td>
#              $8.03
#             </td>
#             <td>
#              $7.88
#             </td>
#             <td>
#              $7.95
#             </td>
#             <td>
#              $7.90
#             </td>
#             <td>
#              $8.09
#             </td>
#             <td>
#              N/A
#             </td>
#             <td>
#              $7.93
#             </td>
#             <td>
#              $7.83
#             </td>
#             <td>
#              $7.95
#             </td>
#             <td>
#              $7.61
#             </td>
#             <td>
#              $7.76
#             </td>
#             <td>
#             </td>
#            </tr>
#            <tr>
#             <td scope="row">
#              2019
#             </td>
#             <td>
#              $7.28
#             </td>
#             <td>
#              $7.54
#             </td>
#             <td>
#              $7.86
#             </td>
#             <td>
#              $7.66
#             </td>
#             <td>
#              $7.66
#             </td>
#             <td>
#              $7.72
#             </td>
#             <td>
#              $7.68
#             </td>
#             <td>
#              $7.62
#             </td>
#             <td>
#              $7.89
#             </td>
#             <td>
#              $7.71
#             </td>
#             <td>
#              $7.85
#             </td>
#             <td>
#              $8.08
#             </td>
#            </tr>
#            <tr>
#             <td scope="row">
#              2018
#             </td>
#             <td>
#              $7.57
#             </td>
#             <td>
#              $7.22
#             </td>
#             <td>
#              $7.34
#             </td>
#             <td>
#              $7.28
#             </td>
#             <td>
#              $7.03
#             </td>
#             <td>
#              $7.23
#             </td>
#             <td>
#              $7.37
#             </td>
#             <td>
#              $7.41
#             </td>
#             <td>
#              $7.17
#             </td>
#             <td>
#              $7.34
#             </td>
#             <td>
#              $7.51
#             </td>
#             <td>
#              $7.46
#             </td>
#            </tr>
#            <tr>
#             <td scope="row">
#              2017
#             </td>
#             <td>
#              $7.35
#             </td>
#             <td>
#              $6.99
#             </td>
#             <td>
#              $6.85
#             </td>
#             <td>
#              $7.04
#             </td>
#             <td>
#              $7.06
#             </td>
#             <td>
#              $7.25
#             </td>
#             <td>
#              $7.05
#             </td>
#             <td>
#              $7.26
#             </td>
#             <td>
#              $7.27
#             </td>
#             <td>
#              $7.37
#             </td>
#             <td>
#              $7.18
#             </td>
#             <td>
#              $7.25
#             </td>
#            </tr>
#            <tr>
#             <td scope="row">
#              2016
#             </td>
#             <td>
#              $6.74
#             </td>
#             <td>
#              $6.91
#             </td>
#             <td>
#              $6.79
#             </td>
#             <td>
#              $6.79
#             </td>
#             <td>
#              $6.72
#             </td>
#             <td>
#              $7.12
#             </td>
#             <td>
#              $7.01
#             </td>
#             <td>
#              $6.88
#             </td>
#             <td>
#              $6.88
#             </td>
#             <td>
#              $7.12
#             </td>
#             <td>
#              $7.04
#             </td>
#             <td>
#              $7.39
#             </td>
#            </tr>
#            <tr>
#             <td scope="row">
#              2015
#             </td>
#             <td>
#              $6.65
#             </td>
#             <td>
#              $6.43
#             </td>
#             <td>
#              $6.57
#             </td>
#             <td>
#              $6.49
#             </td>
#             <td>
#              $6.52
#             </td>
#             <td>
#              $6.56
#             </td>
#             <td>
#              $6.73
#             </td>
#             <td>
#              $6.75
#             </td>
#             <td>
#              $6.63
#             </td>
#             <td>
#              $6.69
#             </td>
#             <td>
#              $6.92
#             </td>
#             <td>
#              $6.79
#             </td>
#            </tr>
#            <tr>
#             <td scope="row">
#              2014
#             </td>
#             <td>
#              $5.98
#             </td>
#             <td>
#              $6.17
#             </td>
#             <td>
#              $6.17
#             </td>
#             <td>
#              $6.04
#             </td>
#             <td>
#              $6.40
#             </td>
#             <td>
#              $6.32
#             </td>
#             <td>
#              $6.18
#             </td>
#             <td>
#              $6.32
#             </td>
#             <td>
#              $6.37
#             </td>
#             <td>
#              $6.38
#             </td>
#             <td>
#              $6.31
#             </td>
#             <td>
#              $6.34
#             </td>
#            </tr>
#            <tr>
#             <td scope="row">
#              2013
#             </td>
#             <td>
#              $5.67
#             </td>
#             <td>
#              $5.83
#             </td>
#             <td>
#              $5.68
#             </td>
#             <td>
#              $5.73
#             </td>
#             <td>
#              $5.87
#             </td>
#             <td>
#              $5.81
#             </td>
#             <td>
#              $6.00
#             </td>
#             <td>
#              $5.97
#             </td>
#             <td>
#              $5.82
#             </td>
#             <td>
#              $5.97
#             </td>
#             <td>
#              $5.92
#             </td>
#             <td>
#              $6.04
#             </td>
#            </tr>
#            <tr>
#             <td scope="row">
#              2012
#             </td>
#             <td>
#              $5.26
#             </td>
#             <td>
#              $5.43
#             </td>
#             <td>
#              $5.42
#             </td>
#             <td>
#              $5.56
#             </td>
#             <td>
#              $5.65
#             </td>
#             <td>
#              $5.32
#             </td>
#             <td>
#              $5.67
#             </td>
#             <td>
#              $5.59
#             </td>
#             <td>
#              $5.73
#             </td>
#             <td>
#              $5.57
#             </td>
#             <td>
#              $5.63
#             </td>
#             <td>
#              $5.78
#             </td>
#            </tr>
#            <tr>
#             <td scope="row">
#              2011
#             </td>
#             <td>
#              $4.94
#             </td>
#             <td>
#              $5.02
#             </td>
#             <td>
#              $5.10
#             </td>
#             <td>
#              $5.22
#             </td>
#             <td>
#              $5.19
#             </td>
#             <td>
#              $5.04
#             </td>
#             <td>
#              $5.23
#             </td>
#             <td>
#              $5.17
#             </td>
#             <td>
#              $5.17
#             </td>
#             <td>
#              $5.23
#             </td>
#             <td>
#              $5.22
#             </td>
#             <td>
#              $5.31
#             </td>
#            </tr>
#            <tr>
#             <td scope="row">
#              2010
#             </td>
#             <td>
#              $4.82
#             </td>
#             <td>
#              $4.62
#             </td>
#             <td>
#              $4.73
#             </td>
#             <td>
#              $4.60
#             </td>
#             <td>
#              $4.66
#             </td>
#             <td>
#              $4.81
#             </td>
#             <td>
#              $4.91
#             </td>
#             <td>
#              $5.04
#             </td>
#             <td>
#              $4.98
#             </td>
#             <td>
#              $4.91
#             </td>
#             <td>
#              $5.08
#             </td>
#             <td>
#              $5.06
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <style>
#      #block_1_subNavigation{ margin:; padding:; }
#                     #block_2_contentGrid{ margin:; padding:; }
#                     #block_3_table{ margin:; padding:0px 0px 30px 0px; }
#     </style>
#    </main>
#    <footer class="hidden-print" id="footer">
#     <div class="container">
#      <div class="row">
#       <div class="col-12 col-lg-4 footer-logo">
#        <a href="https://honey.com/">
#         <img alt="" class="img-fluid" src="/images/default/homepage-footer-logo.png" title="National Honey Board"/>
#        </a>
#       </div>
#       <div class="col-12 col-lg-8 footer-nav">
#        <ul class="navbar-nav">
#         <li class="nav-item">
#          <a class="gold bold nav-link" href="https://honey.com/">
#           Home
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="gold bold nav-link" href="https://honey.com/about-honey">
#           About Honey
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="gold bold nav-link" href="https://honey.com/bees-sustainability">
#           Bees &amp; Sustainability
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="gold bold nav-link" href="https://honey.com/recipes">
#           Recipes
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="gold bold nav-link" href="/honey-locator">
#           Locator
#          </a>
#         </li>
#        </ul>
#        <ul class="navbar-nav">
#         <li class="nav-item">
#          <span class="nav-link bold">
#           INDUSTRY &amp; PARTNERS
#          </span>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/">
#           Consumers
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/foodservice">
#           Foodservice
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/food-processors">
#           Food Processors
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/retail">
#           Retail
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link active" href="https://honey.com/honey-industry">
#           Industry
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/nutrition">
#           Nutrition Home
#          </a>
#         </li>
#        </ul>
#        <ul class="navbar-nav">
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/about-the-nhb">
#           About NHB
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/blog">
#           Blog
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/faq">
#           FAQ
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/newsroom">
#           Newsroom
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/contact">
#           Contact
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://honey.com/newsletter">
#           E-newsletter
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="/shop" rel="noopener" target="_blank">
#           NHB Store
#          </a>
#         </li>
#        </ul>
#        <ul class="social-list navbar-nav">
#         <li>
#          <a class="svg" href="https://www.facebook.com/NationalHoneyBoard" target="_blank">
#           <i class="fab fa-facebook-f">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="svg" href="https://www.pinterest.com/nationalhoney/" target="_blank">
#           <i class="fab fa-pinterest-p">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="svg" href="https://www.instagram.com/nationalhoneyboard/" target="_blank">
#           <i class="fab fa-instagram">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="svg" href="https://twitter.com/NationalHoney" target="_blank">
#           <i class="fab fa-twitter">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="svg" href="https://www.youtube.com/user/NationalHoneyBoard" target="_blank">
#           <i class="fab fa-youtube">
#           </i>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-12 copyright">
#        <p class="small">
#         © 2020 National Honey Board. All Right Reserved.
#        </p>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <script src="/assets/js/main.js">
#   </script>
#   <!-- Go to www.addthis.com/dashboard to customize your tools -->
#   <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-563d2055d7929299" type="text/javascript">
#   </script>
#   <div id="ccc">
#    <cookie-banner>
#    </cookie-banner>
#   </div>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org","@graph":[{"@type":"WebPage","author":{"@id":"#identity"},"copyrightHolder":{"@id":"#identity"},"copyrightYear":"2020-02-06T09:29:00-08:00","creator":{"@id":"#creator"},"dateModified":"2020-12-16T16:30:49-08:00","datePublished":"2020-02-06T09:29:00-08:00","headline":"Retail Honey Prices","inLanguage":"en-us","mainEntityOfPage":"https://honey.com/honey-industry/statistics/retail-honey-price","name":"Retail Honey Prices","publisher":{"@id":"#creator"},"url":"https://honey.com/honey-industry/statistics/retail-honey-price"},{"@id":"#identity","@type":"Corporation"},{"@id":"#creator","@type":"Organization"},{"@type":"BreadcrumbList","description":"Breadcrumbs list","itemListElement":[{"@type":"ListItem","item":"https://honey.com/","name":"Home","position":1},{"@type":"ListItem","item":"https://honey.com/honey-industry","name":"Industry","position":2},{"@type":"ListItem","item":"https://honey.com/honey-industry/statistics","name":"Statistics","position":3},{"@type":"ListItem","item":"https://honey.com/honey-industry/statistics/retail-honey-price","name":"Retail Honey Prices","position":4}],"name":"Breadcrumbs"}]}
#   </script>
#   <script src="https://honey.com/cpresources/654bcd49/ccc.js?v=1608136305">
#   </script>
#  </body>
# </html>

# %%
tb = soup.find('table', class_='wikitable')

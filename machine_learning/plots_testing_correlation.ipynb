# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.filterwarnings(action='once')

# %%
large = 22; med = 16; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (16, 10),
          'axes.labelsize': med,
          'axes.titlesize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
plt.rcParams.update(params)
plt.style.use('seaborn-whitegrid')
sns.set_style("white")
# %matplotlib inline

# %%
bee_data = pd.read_csv("../bee_data/machine_learning_dataset.csv")
honey_prices = pd.read_csv("../asia/honey_prices.csv")
pumpkins = pd.read_csv("../bee_data/pumpkins_v2.csv")
almonds = pd.read_csv("../bee_data/2almonds.csv")
cherries = pd.read_csv("../bee_data/sweet_cherries.csv")
honey = pd.read_csv("../bee_data/6honey.csv")

bee_data.head()
# Out:
#    year       state  deadout  cc_syn  pesticides  lbs_of_honey  \
# 0  2019     ALABAMA     2300     430         5.4         44000
# 1  2019     ARIZONA    11500    5670        50.9        201000
# 2  2019    ARKANSAS    10200    1870       113.6        176000
# 3  2019  CALIFORNIA   464000   44500        39.6       3216000
# 4  2019    COLORADO    17820    4600        25.5        500000
#
#    count_colonies  extreme_temp_days
# 0            6166                 16
# 1           27333                 24
# 2           22333                 51
# 3          830000                  0
# 4           21666                136

# %%
# plt.figure(figsize=(10, 10), dpi= 80)
# sns.pairplot(bee_data, kind="scatter", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
# plt.show()

# %%
sns.set(color_codes=True)
sns.regplot(x="pesticides",y="deadout",data=bee_data, color="black");
plt.figure(figsize=(30, 30), dpi= 80)

# %%
sns.set(color_codes=True)
sns.regplot(x="cc_syn",y="deadout",data=bee_data, color="gold");
plt.figure(figsize=(30, 30), dpi= 80)

# %%
sns.set(color_codes=True)
sns.regplot(x="extreme_temp_days",y="deadout",data=bee_data, color="black");
plt.figure(figsize=(30, 30), dpi= 80)

# %%
sns.set(color_codes=True)
sns.regplot(x="count_colonies",y="lbs_of_honey",data=bee_data, color="gold");
plt.figure(figsize=(30, 30), dpi= 80)

# %%
# lbs_of_honey = bee_data['lbs_of_honey'].tolist()
# deadout = bee_data['deadout'].tolist()

# %%
sns.set(style="ticks")

rs = bee_data
x = rs.count_colonies   
y = rs.lbs_of_honey 

sns.jointplot(x=x, y=y, kind="hex", color="gold")
plt.yscale('linear')

# %%
sns.set(style="ticks")

rs = honey_prices
x = rs.year 
y = rs.jan 

sns.jointplot(x=x, y=y, kind="hex", color="gold")

# %%
sns.set(style="ticks")

rs = honey_prices
x = rs.year 
y = rs.apr 

sns.jointplot(x=x, y=y, kind="hex", color="gold")

# %%
sns.set(style="ticks")

rs = honey_prices
x = rs.year 
y = rs.jul 

sns.jointplot(x=x, y=y, kind="hex", color="gold")

# %%
sns.set(style="ticks")

rs = honey_prices
x = rs.year 
y = rs.oct 

sns.jointplot(x=x, y=y, kind="hex", color="gold")

# %%
# Out:
#   Program  Year Period  Week Ending Geo Level       State  State ANSI  \
# 0  SURVEY  2019   YEAR          NaN  NATIONAL    US TOTAL         NaN
# 1  SURVEY  2019   YEAR          NaN     STATE  CALIFORNIA         6.0
# 2  SURVEY  2019   YEAR          NaN     STATE    ILLINOIS        17.0
# 3  SURVEY  2019   YEAR          NaN     STATE     INDIANA        18.0
# 4  SURVEY  2019   YEAR          NaN     STATE    MICHIGAN        26.0
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
# 1          NaN               NaN     NaN  ...       NaN     NaN
# 2          NaN               NaN     NaN  ...       NaN     NaN
# 3          NaN               NaN     NaN  ...       NaN     NaN
# 4          NaN               NaN     NaN  ...       NaN     NaN
#
#    watershed_code  Watershed  Commodity  \
# 0               0        NaN   PUMPKINS
# 1               0        NaN   PUMPKINS
# ...
